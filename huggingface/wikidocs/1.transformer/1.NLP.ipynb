# %% [markdown]
# ## 1. 자연어처리
#
# ### 태스크 종류 및 예시
#
# 1. 전체 문장 분류
# 2. 단일 문장에서 각 단어 분류
# 3. 텍스트 컨텐트 생성(프롬프트, 마스킹된 단어 등)
# 4. 정답 추출(QA)
# 5. 입력 텍스트에서 새로운 문장 생성(번역, 요약)

# %% [markdown]
# ### 왜 어려운가?
#
# 모델이 자연어처리 태스크를 수행하기 위해서는 모델이 텍스트를 학습할 수 있도록 __처리__되어야 한다.
