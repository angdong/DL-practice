# %% [markdown]
# ## 5. 디코더 모델
#
# * Transformer 모델의 디코더 모듈만 사용
# * 각 단계에서 주어진 단어에 대해 어텐션 레이어는 문장에서 현재 처리하는 단어의 앞쪽에 위치한 단어들만 액세스
# * auto-regressive model
# * 일반적으로 문장의 다음 단어 예측을 수행함으로써 이루어짐
#
# * 태스크
#     1. 텍스트 생성 등...
#
# * 예)
#     1. CTRL
#     2. GPT
#     3. GPT-2
#     4. Transformer XL
